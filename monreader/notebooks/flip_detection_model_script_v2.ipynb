# %%
import tensorflow as tf
from tensorflow.keras import Model, Input, Sequential
from tensorflow.keras.layers import Dense, Input, Conv2D, MaxPooling2D, Flatten
import matplotlib.pyplot as plt
import os
from evaluate_model import evaluate_model, get_data, plot_accuracy, plot_loss
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
# Out:
# WARNING:tensorflow:From C:\Users\KUDIPUDI\.conda\envs\dsEnv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\KUDIPUDI\Documents\Apziva\004_monreader\KUSUzg5h2pSpBosP\monreader\notebooks\evaluate_model.py:10: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.

# %%
shape, classes, data = get_data()
train_data, val_data, test_data = data
# Out:
# Found 2392 files belonging to 2 classes.
# Using 1914 files for training.
# Found 2392 files belonging to 2 classes.
# Using 478 files for validation.
# Found 597 files belonging to 2 classes.

# %%
inputs = Input(shape= shape)
layer1 = Conv2D(filters=64, kernel_size=(3, 3), activation='relu')(inputs)
layer2 = MaxPooling2D((2,2))(layer1)
layer3 = Conv2D(filters=32, kernel_size=(3, 3), activation='relu')(layer2)
layer4 = MaxPooling2D((2,2))(layer3)
layer5 = Flatten()(layer4)
layer6 = Dense(16, activation='relu')(layer5)
outputs = Dense(len(classes), activation='softmax')(layer6)
fd_model = Model(inputs=inputs, outputs=outputs)

fd_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
fd_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  conv2d (Conv2D)             (None, 178, 178, 64)      1792
#
#  max_pooling2d (MaxPooling2  (None, 89, 89, 64)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 32)        18464
#
#  max_pooling2d_1 (MaxPoolin  (None, 43, 43, 32)        0
#  g2D)
#
#  flatten (Flatten)           (None, 59168)             0
#
#  dense (Dense)               (None, 16)                946704
#
#  dense_1 (Dense)             (None, 2)                 34
#
# =================================================================
# Total params: 966994 (3.69 MB)
# Trainable params: 966994 (3.69 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
fd_model_hist = fd_model.fit(
  train_data,
  validation_data=val_data,
  epochs=20
)
# Out:
# Epoch 1/20
# 60/60 [==============================] - 18s 291ms/step - loss: 7.9679 - accuracy: 0.6364 - val_loss: 0.4295 - val_accuracy: 0.8096
# Epoch 2/20
# 60/60 [==============================] - 20s 330ms/step - loss: 0.3731 - accuracy: 0.8422 - val_loss: 0.7652 - val_accuracy: 0.8285
# Epoch 3/20
# 60/60 [==============================] - 20s 330ms/step - loss: 0.1889 - accuracy: 0.9284 - val_loss: 0.1426 - val_accuracy: 0.9477
# Epoch 4/20
# 60/60 [==============================] - 20s 332ms/step - loss: 0.0667 - accuracy: 0.9754 - val_loss: 0.1355 - val_accuracy: 0.9310
# Epoch 5/20
# 60/60 [==============================] - 20s 333ms/step - loss: 0.0700 - accuracy: 0.9749 - val_loss: 0.1447 - val_accuracy: 0.9582
# Epoch 6/20
# 60/60 [==============================] - 20s 331ms/step - loss: 0.0429 - accuracy: 0.9833 - val_loss: 0.1770 - val_accuracy: 0.9289
# Epoch 7/20
# 60/60 [==============================] - 20s 331ms/step - loss: 0.0555 - accuracy: 0.9807 - val_loss: 0.1304 - val_accuracy: 0.9477
# Epoch 8/20
# 60/60 [==============================] - 20s 333ms/step - loss: 0.0179 - accuracy: 0.9958 - val_loss: 0.1104 - val_accuracy: 0.9603
# Epoch 9/20
# 60/60 [==============================] - 20s 333ms/step - loss: 0.0068 - accuracy: 0.9990 - val_loss: 0.0945 - val_accuracy: 0.9603
# Epoch 10/20
# 60/60 [==============================] - 21s 339ms/step - loss: 0.0122 - accuracy: 0.9984 - val_loss: 0.2154 - val_accuracy: 0.9498
# Epoch 11/20
# 60/60 [==============================] - 21s 339ms/step - loss: 0.0152 - accuracy: 0.9943 - val_loss: 0.0959 - val_accuracy: 0.9686
# Epoch 12/20
# 60/60 [==============================] - 21s 339ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0863 - val_accuracy: 0.9686
# Epoch 13/20
# 60/60 [==============================] - 21s 339ms/step - loss: 4.1562e-04 - accuracy: 1.0000 - val_loss: 0.0842 - val_accuracy: 0.9728
# Epoch 14/20
# 60/60 [==============================] - 21s 338ms/step - loss: 2.8870e-04 - accuracy: 1.0000 - val_loss: 0.0866 - val_accuracy: 0.9791
# Epoch 15/20
# 60/60 [==============================] - 21s 338ms/step - loss: 1.5905e-04 - accuracy: 1.0000 - val_loss: 0.0868 - val_accuracy: 0.9791
# Epoch 16/20
# 60/60 [==============================] - 21s 337ms/step - loss: 1.2698e-04 - accuracy: 1.0000 - val_loss: 0.0872 - val_accuracy: 0.9791
# Epoch 17/20
# 60/60 [==============================] - 21s 336ms/step - loss: 1.0525e-04 - accuracy: 1.0000 - val_loss: 0.0873 - val_accuracy: 0.9770
# Epoch 18/20
# 60/60 [==============================] - 21s 339ms/step - loss: 8.7241e-05 - accuracy: 1.0000 - val_loss: 0.0865 - val_accuracy: 0.9770
# Epoch 19/20
# 60/60 [==============================] - 21s 337ms/step - loss: 7.3666e-05 - accuracy: 1.0000 - val_loss: 0.0866 - val_accuracy: 0.9770
# Epoch 20/20
# 60/60 [==============================] - 20s 335ms/step - loss: 6.3920e-05 - accuracy: 1.0000 - val_loss: 0.0870 - val_accuracy: 0.9770

# %%
plot_accuracy(fd_model_hist, "Flip Detection Model")

# %%
plot_loss(fd_model_hist, "Flip Detection Model")

# %%
evaluate_model(fd_model, test_data)
# Out:
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 109ms/step
# {'accuracy': 0.9765494137353434, 'f1_score': 0.9774193548387097}

# %%
fd_model_path = '../models/fd_model_v2.h5'
fd_model.save(fd_model_path)
fd_model_size = os.path.getsize(fd_model_path) / (1024 * 1024)
print('Model size: ', fd_model_size, 'MB')
# Out:
# Model size:  11.1087646484375 MB
