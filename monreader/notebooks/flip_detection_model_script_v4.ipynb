# %%
import tensorflow as tf
from tensorflow.keras import Model, Input, Sequential
from tensorflow.keras.layers import Dense, Input, Conv2D, MaxPooling2D, Flatten
import matplotlib.pyplot as plt
import os
from evaluate_model import evaluate_model, get_data, plot_accuracy, plot_loss
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
# Out:
# WARNING:tensorflow:From C:\Users\KUDIPUDI\.conda\envs\dsEnv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\KUDIPUDI\Documents\Apziva\004_monreader\KUSUzg5h2pSpBosP\monreader\notebooks\evaluate_model.py:10: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.

# %%
shape, classes, data = get_data()
train_data, val_data, test_data = data
# Out:
# Found 2392 files belonging to 2 classes.
# Using 1914 files for training.
# Found 2392 files belonging to 2 classes.
# Using 478 files for validation.
# Found 597 files belonging to 2 classes.

# %%
inputs = Input(shape= shape)
layer1 = Conv2D(filters=64, kernel_size=(3, 3), activation='relu')(inputs)
layer2 = MaxPooling2D((2,2))(layer1)
layer3 = Conv2D(filters=32, kernel_size=(3, 3), activation='relu')(layer2)
layer4 = MaxPooling2D((2,2))(layer3)
layer5 = Conv2D(filters=16, kernel_size=(3, 3), activation='relu')(layer4)
layer6 = MaxPooling2D((2,2))(layer5)
layer7 = Flatten()(layer6)
layer8 = Dense(32, activation='relu')(layer7)
outputs = Dense(len(classes), activation='softmax')(layer8)
fd_model = Model(inputs=inputs, outputs=outputs)

fd_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
fd_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  conv2d (Conv2D)             (None, 178, 178, 64)      1792
#
#  max_pooling2d (MaxPooling2  (None, 89, 89, 64)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 32)        18464
#
#  max_pooling2d_1 (MaxPoolin  (None, 43, 43, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 41, 41, 16)        4624
#
#  max_pooling2d_2 (MaxPoolin  (None, 20, 20, 16)        0
#  g2D)
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense (Dense)               (None, 32)                204832
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 229778 (897.57 KB)
# Trainable params: 229778 (897.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
fd_model_hist = fd_model.fit(
  train_data,
  validation_data=val_data,
  epochs=20
)
# Out:
# Epoch 1/20
# 60/60 [==============================] - 19s 297ms/step - loss: 3.2622 - accuracy: 0.6050 - val_loss: 0.5631 - val_accuracy: 0.7469
# Epoch 2/20
# 60/60 [==============================] - 20s 323ms/step - loss: 0.4933 - accuracy: 0.7759 - val_loss: 0.4144 - val_accuracy: 0.8285
# Epoch 3/20
# 60/60 [==============================] - 20s 324ms/step - loss: 0.3956 - accuracy: 0.8380 - val_loss: 0.3158 - val_accuracy: 0.8640
# Epoch 4/20
# 60/60 [==============================] - 20s 325ms/step - loss: 0.3937 - accuracy: 0.8417 - val_loss: 0.2955 - val_accuracy: 0.8828
# Epoch 5/20
# 60/60 [==============================] - 20s 324ms/step - loss: 0.2859 - accuracy: 0.8788 - val_loss: 0.2613 - val_accuracy: 0.8891
# Epoch 6/20
# 60/60 [==============================] - 20s 329ms/step - loss: 0.2071 - accuracy: 0.9164 - val_loss: 0.2825 - val_accuracy: 0.8891
# Epoch 7/20
# 60/60 [==============================] - 20s 329ms/step - loss: 0.2220 - accuracy: 0.9117 - val_loss: 0.1914 - val_accuracy: 0.9310
# Epoch 8/20
# 60/60 [==============================] - 20s 330ms/step - loss: 0.1033 - accuracy: 0.9639 - val_loss: 0.1687 - val_accuracy: 0.9498
# Epoch 9/20
# 60/60 [==============================] - 20s 336ms/step - loss: 0.0832 - accuracy: 0.9713 - val_loss: 0.1568 - val_accuracy: 0.9540
# Epoch 10/20
# 60/60 [==============================] - 21s 336ms/step - loss: 0.0509 - accuracy: 0.9833 - val_loss: 0.1594 - val_accuracy: 0.9707
# Epoch 11/20
# 60/60 [==============================] - 20s 334ms/step - loss: 0.0562 - accuracy: 0.9775 - val_loss: 0.1084 - val_accuracy: 0.9665
# Epoch 12/20
# 60/60 [==============================] - 21s 338ms/step - loss: 0.0524 - accuracy: 0.9796 - val_loss: 0.1004 - val_accuracy: 0.9686
# Epoch 13/20
# 60/60 [==============================] - 21s 338ms/step - loss: 0.0225 - accuracy: 0.9932 - val_loss: 0.1035 - val_accuracy: 0.9770
# Epoch 14/20
# 60/60 [==============================] - 21s 338ms/step - loss: 0.0848 - accuracy: 0.9624 - val_loss: 0.2999 - val_accuracy: 0.8891
# Epoch 15/20
# 60/60 [==============================] - 21s 338ms/step - loss: 0.1251 - accuracy: 0.9509 - val_loss: 0.1097 - val_accuracy: 0.9623
# Epoch 16/20
# 60/60 [==============================] - 21s 337ms/step - loss: 0.0359 - accuracy: 0.9859 - val_loss: 0.1143 - val_accuracy: 0.9665
# Epoch 17/20
# 60/60 [==============================] - 20s 335ms/step - loss: 0.0203 - accuracy: 0.9948 - val_loss: 0.0759 - val_accuracy: 0.9707
# Epoch 18/20
# 60/60 [==============================] - 21s 338ms/step - loss: 0.0095 - accuracy: 0.9979 - val_loss: 0.0977 - val_accuracy: 0.9686
# Epoch 19/20
# 60/60 [==============================] - 20s 335ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 0.9770
# Epoch 20/20
# 60/60 [==============================] - 21s 341ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1119 - val_accuracy: 0.9728

# %%
plot_accuracy(fd_model_hist, "Flip Detection Model")

# %%
plot_loss(fd_model_hist, "Flip Detection Model")

# %%
evaluate_model(fd_model, test_data)
# Out:
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 109ms/step
# {'accuracy': 0.9782244556113903, 'f1_score': 0.9792}

# %%
fd_model_path = '../models/fd_model_v4.h5'
fd_model.save(fd_model_path)
fd_model_size = os.path.getsize(fd_model_path) / (1024 * 1024)
print('Model size: ', fd_model_size, 'MB')
# Out:
# Model size:  2.6797714233398438 MB
