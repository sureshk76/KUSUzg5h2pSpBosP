# %%
import tensorflow as tf
from tensorflow.keras import Model, Input, Sequential
from tensorflow.keras.layers import Dense, Input, Conv2D, MaxPooling2D, Flatten
import matplotlib.pyplot as plt
import os
from evaluate_model import evaluate_model, get_data, plot_accuracy, plot_loss
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
# Out:
# WARNING:tensorflow:From C:\Users\KUDIPUDI\.conda\envs\dsEnv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\KUDIPUDI\Documents\Apziva\004_monreader\KUSUzg5h2pSpBosP\monreader\notebooks\evaluate_model.py:10: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.

# %%
shape, classes, data = get_data()
train_data, val_data, test_data = data
# Out:
# Found 2392 files belonging to 2 classes.
# Using 1914 files for training.
# Found 2392 files belonging to 2 classes.
# Using 478 files for validation.
# Found 597 files belonging to 2 classes.

# %%
inputs = Input(shape= shape)
layer1 = Conv2D(filters=64, kernel_size=(3, 3), activation='relu')(inputs)
layer2 = MaxPooling2D((2,2))(layer1)
layer3 = Conv2D(filters=32, kernel_size=(3, 3), activation='relu')(layer2)
layer4 = MaxPooling2D((2,2))(layer3)
layer5 = Conv2D(filters=32, kernel_size=(3, 3), activation='relu')(layer4)
layer6 = MaxPooling2D((2,2))(layer5)
layer7 = Conv2D(filters=16, kernel_size=(3, 3), activation='relu')(layer6)
layer8 = Flatten()(layer7)
layer9 = Dense(32, activation='relu')(layer8)
outputs = Dense(len(classes), activation='softmax')(layer9)
fd_model = Model(inputs=inputs, outputs=outputs)

fd_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
fd_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  conv2d (Conv2D)             (None, 178, 178, 64)      1792
#
#  max_pooling2d (MaxPooling2  (None, 89, 89, 64)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 32)        18464
#
#  max_pooling2d_1 (MaxPoolin  (None, 43, 43, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 41, 41, 32)        9248
#
#  max_pooling2d_2 (MaxPoolin  (None, 20, 20, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 18, 18, 16)        4624
#
#  flatten (Flatten)           (None, 5184)              0
#
#  dense (Dense)               (None, 32)                165920
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 200114 (781.70 KB)
# Trainable params: 200114 (781.70 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
fd_model_hist = fd_model.fit(
  train_data,
  validation_data=val_data,
  epochs=20
)
# Out:
# Epoch 1/20
# 60/60 [==============================] - 18s 290ms/step - loss: 2.1348 - accuracy: 0.5700 - val_loss: 0.6206 - val_accuracy: 0.5983
# Epoch 2/20
# 60/60 [==============================] - 20s 333ms/step - loss: 0.5934 - accuracy: 0.6505 - val_loss: 0.5636 - val_accuracy: 0.7218
# Epoch 3/20
# 60/60 [==============================] - 20s 327ms/step - loss: 0.5538 - accuracy: 0.7226 - val_loss: 0.6239 - val_accuracy: 0.6674
# Epoch 4/20
# 60/60 [==============================] - 20s 329ms/step - loss: 0.6166 - accuracy: 0.6557 - val_loss: 0.5854 - val_accuracy: 0.7071
# Epoch 5/20
# 60/60 [==============================] - 20s 325ms/step - loss: 0.5701 - accuracy: 0.7069 - val_loss: 0.5916 - val_accuracy: 0.7134
# Epoch 6/20
# 60/60 [==============================] - 20s 329ms/step - loss: 0.5191 - accuracy: 0.7461 - val_loss: 0.5298 - val_accuracy: 0.7490
# Epoch 7/20
# 60/60 [==============================] - 21s 336ms/step - loss: 0.4836 - accuracy: 0.7785 - val_loss: 0.5165 - val_accuracy: 0.7510
# Epoch 8/20
# 60/60 [==============================] - 20s 335ms/step - loss: 0.4114 - accuracy: 0.8135 - val_loss: 0.3662 - val_accuracy: 0.8619
# Epoch 9/20
# 60/60 [==============================] - 21s 339ms/step - loss: 0.2751 - accuracy: 0.8892 - val_loss: 0.3470 - val_accuracy: 0.8703
# Epoch 10/20
# 60/60 [==============================] - 21s 342ms/step - loss: 0.1427 - accuracy: 0.9478 - val_loss: 0.1453 - val_accuracy: 0.9603
# Epoch 11/20
# 60/60 [==============================] - 21s 349ms/step - loss: 0.5106 - accuracy: 0.8506 - val_loss: 0.3583 - val_accuracy: 0.8598
# Epoch 12/20
# 60/60 [==============================] - 21s 344ms/step - loss: 0.3228 - accuracy: 0.8657 - val_loss: 0.3448 - val_accuracy: 0.8703
# Epoch 13/20
# 60/60 [==============================] - 21s 347ms/step - loss: 0.2796 - accuracy: 0.8997 - val_loss: 0.2409 - val_accuracy: 0.8954
# Epoch 14/20
# 60/60 [==============================] - 21s 346ms/step - loss: 0.1329 - accuracy: 0.9530 - val_loss: 0.1920 - val_accuracy: 0.9372
# Epoch 15/20
# 60/60 [==============================] - 21s 343ms/step - loss: 0.0974 - accuracy: 0.9666 - val_loss: 0.1048 - val_accuracy: 0.9686
# Epoch 16/20
# 60/60 [==============================] - 21s 346ms/step - loss: 0.1133 - accuracy: 0.9639 - val_loss: 0.2163 - val_accuracy: 0.9226
# Epoch 17/20
# 60/60 [==============================] - 21s 352ms/step - loss: 0.0681 - accuracy: 0.9765 - val_loss: 0.0878 - val_accuracy: 0.9791
# Epoch 18/20
# 60/60 [==============================] - 21s 345ms/step - loss: 0.0492 - accuracy: 0.9822 - val_loss: 0.1839 - val_accuracy: 0.9414
# Epoch 19/20
# 60/60 [==============================] - 21s 349ms/step - loss: 0.0487 - accuracy: 0.9838 - val_loss: 0.0936 - val_accuracy: 0.9770
# Epoch 20/20
# 60/60 [==============================] - 21s 348ms/step - loss: 0.0490 - accuracy: 0.9801 - val_loss: 0.0654 - val_accuracy: 0.9854

# %%
plot_accuracy(fd_model_hist, "Flip Detection Model")

# %%
plot_loss(fd_model_hist, "Flip Detection Model")

# %%
evaluate_model(fd_model, test_data)
# Out:
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 117ms/step
# {'accuracy': 0.9798994974874372, 'f1_score': 0.9803921568627452}

# %%
fd_model_path = '../models/fd_model_v5.h5'
fd_model.save(fd_model_path)
fd_model_size = os.path.getsize(fd_model_path) / (1024 * 1024)
print('Model size: ', fd_model_size, 'MB')
# Out:
# Model size:  2.3460311889648438 MB
